# %%
import random
import threading
import time

# %%
class nodeSlave:
    def __init__(self, id, Pint, sensorRange):
        self.id = id
        self.Pint = Pint
        self.sensorRange = sensorRange
        self.conexoes = []
        self.busy = False

    def leituras(self):
        while(not self.busy):
            summ = 0
            finalRead = 0
            for i in self.sensorRange:
                summ = summ + random.choice(self.sensorRange)
                print("Node {0} with Read {1}".format(self.id,summ))
            finalRead = summ/len(self.sensorRange)
            print("Node {0} with Final Read {1}".format(self.id,finalRead))
            time.sleep(500)
    def stopRead(self, switch):
        print("ENDDDDDDDDDDDDDDDDDDDDD{0}".format(self.id))
        if(switch == -1):
            self.busy = True

# %%
x = nodeSlave(1,50,range(0,10000))
y = nodeSlave(2,100,range(10000,20000))
z = nodeSlave(3,100,range(20000,30000))
functX = threading.Thread(target=x.leituras, args=())
functy = threading.Thread(target=y.leituras, args=())
functz = threading.Thread(target=z.leituras, args=())

functX.start()
functy.start()
functz.start()
functX.join()
functy.join()
functz.join()
# Out:
# Node 1 with Read 475
# Node 1 with Read 962
# Node 1 with Read 2629
# Node 1 with Read 10394
# Node 1 with Read 19708
# Node 1 with Read 24269
# Node 1 with Read 24345
# Node 1 with Read 25216
# Node 1 with Read 27511
# Node 1 with Read 30647
# Node 1 with Read 34176
# Node 1 with Read 38362
# Node 1 with Read 39031
# Node 1 with Read 47736
# Node 1 with Read 53894
# Node 1 with Read 59968
# Node 1 with Read 68591
# Node 1 with Read 72114
# Node 1 with Read 75798
# Node 1 with Read 78295
# Node 1 with Read 83507
# Node 1 with Read 85800
# Node 1 with Read 86802
# Node 1 with Read 88509
# Node 1 with Read 93743
# Node 1 with Read 101194
# Node 1 with Read 106443
# Node 1 with Read 109319
# Node 1 with Read 112174
# Node 2 with Read 17404Node 1 with Read 112379
# Node 2 with Read 28329
# Node 2 with Read 43629
#
# Node 1 with Read 114678
# Node 1 with Read 121229
# Node 1 with Read 124894
# Node 1 with Read 125818
# Node 1 with Read 131304
# Node 1 with Read 133022
# ...

# %%
x.leituras()
